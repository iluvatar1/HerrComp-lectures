# %% [markdown]
# # Mi primer notebook
#
# ajlahasljhdljsadljha ljadhlasjh dlashld ahljdh ldsalda
#
# ## Sec 1
#
# ## Sec 2 nsdfdsfsd

# %%
print("Hola mundo")
# Out:
# Hola mundo

# %% [markdown]
# # Ejecucion de comandos de consola
# Se utiliza un prefijo: `!`

# %%
# !ls
# Out:
# Untitled.ipynb  hw.py

# %% [markdown]
# # Como crear un archivo .py y ejecutarlo

# %%
# %%writefile ex1.py
print("Hello world")
# Out:
# Writing ex1.py

# %%
# !python ex1.py
# Out:
# Hello world

# %% [markdown]
# # Como crear figuras

# %%
# %matplotlib inline
import numpy as np
#import matplotlib.pyplot as plt
from matplotlib import pyplot as plt

# Data setup
x = np.linspace(-10.890, 5.432, 100)
y = 2*np.sin(np.cos(x))

# plot
plt.plot(x, y)

# %% [markdown]
# # Printing

# %%
mystring = "nombre"
print(mystring)
# Out:
# nombre

# %%
print("Hola como estas : %s"% mystring)
print("Hola como estas : {}".format(mystring))
# Out:
# Hola como estas : nombre
# Hola como estas : nombre

# %%
print(f"Hola como estas : {fun(9.876544):08.3}")
# Out:
# Hola como estas : 00009.88
